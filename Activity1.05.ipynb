# %% [markdown]
# # 1.05 Activity 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the merged_clean_ver1.csv file.
data = pd.read_csv("merged_clean_ver1.csv")

# %%
data
# Out:
#       Unnamed: 0      id state gender  median_home_val  \
# 0              0   44060    FL      M      1158.437751
# 1              1   96093    IL      M       537.000000
# 2              2   43333    FL      F       725.000000
# 3              3   21885    NC      M      1158.437751
# 4              4  190108    FL      F       995.000000
# ...          ...     ...   ...    ...              ...
# 3988         996   66762    MI      F       632.000000
# 3989         997    6443    FL      M       595.000000
# 3990         998  151175    CA      F      2707.000000
# 3991         999  151504    CA      M      2666.000000
# 3992        1000   74303    MI      M       444.000000
#
#       median_household_income    ic2  ic3    ic4      ic5    avggift  target_d
# 0                         392  430.0  466  520.0  21975.0  28.000000     100.0
# 1                         365  415.0  410  473.0  19387.0   5.666667       7.0
# ...

# %%
# Check the data types of all columns in the dataframe.
data.dtypes
# Out:
# Unnamed: 0                   int64
# id                           int64
# state                       object
# gender                      object
# median_home_val            float64
# median_household_income      int64
# ic2                        float64
# ic3                          int64
# ic4                        float64
# ic5                        float64
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
# Use the describe method on only the float type columns.
data.describe(include=(np.float64))
# Out:
#        median_home_val          ic2          ic4            ic5      avggift  \
# count      3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean       1158.437751   400.713248   444.732031   16456.413724    11.785117
# std        1033.485773   180.568500   175.004178    9455.318118    10.172672
# min           0.000000     0.000000     0.000000       0.000000     2.260870
# 25%         548.000000   284.000000   325.000000   11136.000000     7.187500
# 50%         803.000000   366.000000   410.000000   14356.000000    10.000000
# 75%        1349.000000   478.000000   528.000000   18780.000000    14.428571
# max        5982.000000  1500.000000  1331.000000  174523.000000   450.000000
#
#           target_d
# count  3993.000000
# mean     15.665036
# std      12.703041
# min       1.000000
# 25%      10.000000
# 50%      14.000000
# 75%      20.000000
# max     200.000000

# %%
# Use the describe method on only the float type columns.
data['ic2'].describe()
# Out:
# count    3993.000000
# mean      400.713248
# std       180.568500
# min         0.000000
# 25%       284.000000
# 50%       366.000000
# 75%       478.000000
# max      1500.000000
# Name: ic2, dtype: float64

# %%
data['median_home_val'].describe()
# Out:
# count    3993.000000
# mean     1158.437751
# std      1033.485773
# min         0.000000
# 25%       548.000000
# 50%       803.000000
# 75%      1349.000000
# max      5982.000000
# Name: median_home_val, dtype: float64

# %%
data['ic4'].describe()
# Out:
# count    3993.000000
# mean      444.732031
# std       175.004178
# min         0.000000
# 25%       325.000000
# 50%       410.000000
# 75%       528.000000
# max      1331.000000
# Name: ic4, dtype: float64

# %%
data['ic5'].describe()
# Out:
# count      3993.000000
# mean      16456.413724
# std        9455.318118
# min           0.000000
# 25%       11136.000000
# 50%       14356.000000
# 75%       18780.000000
# max      174523.000000
# Name: ic5, dtype: float64

# %%
data['avggift'].describe()
# Out:
# count    3993.000000
# mean       11.785117
# std        10.172672
# min         2.260870
# 25%         7.187500
# 50%        10.000000
# 75%        14.428571
# max       450.000000
# Name: avggift, dtype: float64

# %%
data['target_d'].describe()
# Out:
# count    3993.000000
# mean       15.665036
# std        12.703041
# min         1.000000
# 25%        10.000000
# 50%        14.000000
# 75%        20.000000
# max       200.000000
# Name: target_d, dtype: float64

# %% [markdown]
# # Debate
# ## What is the difference between population mean and sample mean.

# %% [markdown]
# <font color='orange'> Respuesta: La media de la muestra solo considera un numero seleccionado de observaciones, la media poblacional por otro lado, considera todas las observaciones de la poblacion </font>

# %% [markdown]
# # 1.05 Activity 2

# %%
# Get the numeric data.
#Funcion que nos da solo las columnas numericas
data_numerics_only = data.select_dtypes(include=np.number)
data_numerics_only
# Out:
#       Unnamed: 0      id  median_home_val  median_household_income    ic2  \
# 0              0   44060      1158.437751                      392  430.0
# 1              1   96093       537.000000                      365  415.0
# 2              2   43333       725.000000                      301  340.0
# 3              3   21885      1158.437751                      401  407.0
# 4              4  190108       995.000000                      252  280.0
# ...          ...     ...              ...                      ...    ...
# 3988         996   66762       632.000000                      279  336.0
# 3989         997    6443       595.000000                      252  263.0
# 3990         998  151175      2707.000000                      507  504.0
# 3991         999  151504      2666.000000                      535  609.0
# 3992        1000   74303       444.000000                      225  264.0
#
#       ic3    ic4      ic5    avggift  target_d
# ...

# %%
#Aplicamos 
data_numerics_only.describe()
#si quisiera ver solo las columnas objeto , se haria de la siguiente manera
#data_numerics_only.select_dtypes(include=np.objects)
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %%
#Te traspone la tabla
data_numerics_only.describe().T
# Out:
#                           count          mean           std       min  \
# Unnamed: 0               3993.0    499.431255    288.332533   0.00000
# id                       3993.0  98929.308039  58179.839090  12.00000
# median_home_val          3993.0   1158.437751   1033.485773   0.00000
# median_household_income  3993.0    351.622840    168.488445   0.00000
# ic2                      3993.0    400.713248    180.568500   0.00000
# ic3                      3993.0    399.876283    164.822741   0.00000
# ic4                      3993.0    444.732031    175.004178   0.00000
# ic5                      3993.0  16456.413724   9455.318118   0.00000
# avggift                  3993.0     11.785117     10.172672   2.26087
# target_d                 3993.0     15.665036     12.703041   1.00000
#
#                                 25%       50%            75%       max
# Unnamed: 0                 250.0000     499.0     749.000000    1001.0
# ...

# %%
# Print the median
data_numerics_only.median()
# Out:
# Unnamed: 0                    499.0
# id                         101432.0
# median_home_val               803.0
# median_household_income       318.0
# ic2                           366.0
# ic3                           365.0
# ic4                           410.0
# ic5                         14356.0
# avggift                        10.0
# target_d                       14.0
# dtype: float64

# %%
#def funciones para aplicarlo a solo una columna
#Los quartiles es cuando divides tu estadistica en 4 partes
#Los percentiles es cuando divides tu estadistica en 100 segmentos
q3,q1 = np.percentile(data_numerics_only['ic2'],[75,25])
iqr1 =q3-q1   
iqr1
# Out:
# 194.0

# %%
# Definimos la funcion para calcular el IQR en todas las columnas
#RANGO INTERCUARTIL = IQR
def IQR(x):
    return np.subtract(*np.percentile(x,[75,25])) # Aqui simplemente es definir como se calcula el IQR = q3 - q1

# %%
#def funciones ( hay que desarrollarla bien)
q3,q1 = np.percentile(data_numerics_only['ic2'],[75,25])
iqr1 =q3-q1   
iqr1
# Out:
# 194.0

# %%
#Aplicamos la funcion a todas las variables
data_numerics_only.apply(IQR)
# Out:
# Unnamed: 0                    499.000000
# id                         105500.000000
# median_home_val               801.000000
# median_household_income       186.000000
# ic2                           194.000000
# ic3                           193.000000
# ic4                           203.000000
# ic5                          7644.000000
# avggift                         7.241071
# target_d                       10.000000
# dtype: float64

# %% [markdown]
# # 1.05 Activity 3

# %%
data2 = pd.read_csv("merged_clean_ver2.csv")

# %%
data2
# Out:
#       Unnamed: 0      id state  gender  median_home_val  \
# 0              0   44060    FL    Male      1158.437751
# 1              1   96093    IL    Male       537.000000
# 2              2   43333    FL  Female       725.000000
# 3              3   21885    NC    Male      1158.437751
# 4              4  190108    FL  Female       995.000000
# ...          ...     ...   ...     ...              ...
# 3988        3988   66762    MI  Female       632.000000
# 3989        3989    6443    FL    Male       595.000000
# 3990        3990  151175    CA  Female      2707.000000
# 3991        3991  151504    CA    Male      2666.000000
# 3992        3992   74303    MI    Male       444.000000
#
#       median_household_income    ic2  ic3    ic4      ic5    avggift  \
# 0                         392  430.0  466  520.0  21975.0  28.000000
# 1                         365  415.0  410  473.0  19387.0   5.666667
# 2                         301  340.0  361  436.0  18837.0   4.111111
# ...

# %% [markdown]
# <font color='orange'>  Plot Pearson Correlation Heatmap. </font>

# %%
# 
data_num=data.drop(['state','gender','ic2'],axis=1) #Vamos a eliminar las columnas no numericos
data_num
# Out:
#       Unnamed: 0      id  median_home_val  median_household_income  ic3  \
# 0              0   44060      1158.437751                      392  466
# 1              1   96093       537.000000                      365  410
# 2              2   43333       725.000000                      301  361
# 3              3   21885      1158.437751                      401  399
# 4              4  190108       995.000000                      252  316
# ...          ...     ...              ...                      ...  ...
# 3988         996   66762       632.000000                      279  339
# 3989         997    6443       595.000000                      252  262
# 3990         998  151175      2707.000000                      507  538
# 3991         999  151504      2666.000000                      535  612
# 3992        1000   74303       444.000000                      225  269
#
#         ic4      ic5    avggift  target_d
# 0     520.0  21975.0  28.000000     100.0
# ...

# %%
#Calcula la Correlacion
corr_matrixp=data_num.corr(method='pearson')
corr_matrixp
# Out:
#                          Unnamed: 0        id  median_home_val  \
# Unnamed: 0                 1.000000 -0.019174        -0.011188
# id                        -0.019174  1.000000         0.249922
# median_home_val           -0.011188  0.249922         1.000000
# median_household_income   -0.000243  0.099182         0.707209
# ic3                        0.001897  0.105039         0.734526
# ic4                        0.002687  0.098233         0.748761
# ic5                        0.010295  0.072773         0.745223
# avggift                    0.010340 -0.004794         0.138966
# target_d                   0.019956  0.028057         0.116805
#
#                          median_household_income       ic3       ic4  \
# Unnamed: 0                             -0.000243  0.001897  0.002687
# id                                      0.099182  0.105039  0.098233
# median_home_val                         0.707209  0.734526  0.748761
# ...

# %%
plt.figure(figsize=(16, 6)) #Incrementar el Tamaño del Heatmap
heatmap1=sns.heatmap(corr_matrixp,annot=True, cmap='cool') #annot=True para mostrar los valores de correlacion y cambiamos el color
heatmap1.set_title('Pearson Correlation Heatmap', fontdict={'fontsize':20}, pad=10,color='grey') #Le ponemos titulo
# Out:
# Text(0.5, 1.0, 'Pearson Correlation Heatmap')

# %%
#definimos la mascara para establecer los valores del traingulo superior como true
mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en 
heatmap = sns.heatmap(data_num.corr(), mask=mascara, vmax=1, annot=True, cmap='cool') #podemos establecer el valor maximo y minimo
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16, color='grey');
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_18508\1841232615.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en

# %% [markdown]
# <font color='orange'> Plot Spearman Correlation Heatmap. </font>

# %%
#Calcula la correlacion excluyendo los valores nulos
corr_matrixs=data_num.corr(method='spearman')
corr_matrixs
# Out:
#                          Unnamed: 0        id  median_home_val  \
# Unnamed: 0                 1.000000 -0.019375        -0.012329
# id                        -0.019375  1.000000         0.254797
# median_home_val           -0.012329  0.254797         1.000000
# median_household_income    0.000009  0.100530         0.728291
# ic3                       -0.001263  0.107530         0.772365
# ic4                       -0.001742  0.098264         0.771694
# ic5                        0.002953  0.094923         0.760386
# avggift                    0.014665  0.046175         0.162955
# target_d                   0.011910  0.042353         0.134380
#
#                          median_household_income       ic3       ic4  \
# Unnamed: 0                              0.000009 -0.001263 -0.001742
# id                                      0.100530  0.107530  0.098264
# median_home_val                         0.728291  0.772365  0.771694
# ...

# %%
plt.figure(figsize=(16, 6)) #Incrementar el Tamaño del Heatmap
heatmap2=sns.heatmap(corr_matrixs,annot=True, cmap='twilight_shifted') #annot=True para mostrar los valores de correlacion y cambiamos el color
heatmap2.set_title('Spearman Correlation Heatmap', fontdict={'fontsize':20}, pad=10,color='grey') #Le ponemos titulo
# Out:
# Text(0.5, 1.0, 'Spearman Correlation Heatmap')

# %%
#definimos la mascara para establecer los valores del traingulo superior como true
mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en 
heatmap2 = sns.heatmap(data_num.corr(), mask=mascara, vmax=1, annot=True, cmap='twilight_shifted') #podemos establecer el valor maximo y minimo
heatmap2.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16, color='grey');
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_18508\1658329557.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en

# %% [markdown]
# <font color='orange'> Plot Kendall Correlation Heatmap. </font>

# %%
#Calcula la correlacion excluyendo los valores nulos
corr_matrixk=data_num.corr(method='kendall')
corr_matrixk
# Out:
#                          Unnamed: 0        id  median_home_val  \
# Unnamed: 0                 1.000000 -0.012980        -0.007951
# id                        -0.012980  1.000000         0.160365
# median_home_val           -0.007951  0.160365         1.000000
# median_household_income    0.000078  0.063943         0.543534
# ic3                       -0.000712  0.067876         0.585792
# ic4                       -0.001042  0.062002         0.586977
# ic5                        0.001898  0.059639         0.579845
# avggift                    0.009735  0.030927         0.109717
# target_d                   0.008247  0.029435         0.094093
#
#                          median_household_income       ic3       ic4  \
# Unnamed: 0                              0.000078 -0.000712 -0.001042
# id                                      0.063943  0.067876  0.062002
# median_home_val                         0.543534  0.585792  0.586977
# ...

# %%
plt.figure(figsize=(16, 6)) #Incrementar el Tamaño del Heatmap
heatmap3=sns.heatmap(corr_matrixk,annot=True, cmap='PuOr') #annot=True para mostrar los valores de correlacion y cambiamos el color
heatmap3.set_title('Kendall Correlation Heatmap', fontdict={'fontsize':20}, pad=10,color='grey') #Le ponemos titulo
# Out:
# Text(0.5, 1.0, 'Kendall Correlation Heatmap')

# %%
#definimos la mascara para establecer los valores del traingulo superior como true
mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en 
heatmap3 = sns.heatmap(data_num.corr(), mask=mascara, vmax=1, annot=True, cmap='twilight_shifted') #podemos establecer el valor maximo y minimo
heatmap3.set_title('Triangle Kendall Correlation Heatmap', fontdict={'fontsize':18}, pad=16, color='grey')
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_18508\3191238300.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mascara=np.triu(np.ones_like(data_num.corr(), dtype=np.bool)) # aislar el triángulo superior de una matriz mientras convierte todos los valores en el triángulo inferior en
# Text(0.5, 1.0, 'Triangle Kendall Correlation Heatmap')
