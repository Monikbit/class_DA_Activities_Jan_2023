# %% [markdown]
# # 1.04 Activity 1

# %%
import pandas as pd
import numpy as np

# %%
#Load data (file1.csv) in a new Jupyter notebook.
data = pd.read_csv("file1act1.04.csv")

# %%
data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
#Vamos a revisar cuales son los nulos en las columnas ic4 e ic5
sum(data["IC4"].isnull())
# Out:
# 1

# %%
sum(data["IC5"].isnull())
# Out:
# 0

# %%
#vamos a eliminar el registro , debido a que es solo uno, y no deberia representar un cambio muy grande a nuestra base de datos
data['IC4']=data['IC4'].dropna()
data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
#Podemos darnos cuenta que se elimino un registro, ya que ahora la columna tiene una ;longitud de 1006
#No hay datos nulos que eliminar para IC5

# %%
#Use the head() to check the new dataframe.
data.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
#Is it better to fill null values with the mean or with the median?
#Dependera del tipo de distribucion que tengan los datos

# %%
#Can we drop all rows with null values?
#Si con el metodo .dropna

# %% [markdown]
# # 1.04 Activity 2

# %%
#Import the data from merged_clean_ver1.csv as a dataframe. 
data2 = pd.read_csv("merged_clean_ver1.csv")

# %%
data2
# Out:
#       Unnamed: 0      id state gender  median_home_val  \
# 0              0   44060    FL      M      1158.437751
# 1              1   96093    IL      M       537.000000
# 2              2   43333    FL      F       725.000000
# 3              3   21885    NC      M      1158.437751
# 4              4  190108    FL      F       995.000000
# ...          ...     ...   ...    ...              ...
# 3988         996   66762    MI      F       632.000000
# 3989         997    6443    FL      M       595.000000
# 3990         998  151175    CA      F      2707.000000
# 3991         999  151504    CA      M      2666.000000
# 3992        1000   74303    MI      M       444.000000
#
#       median_household_income    ic2  ic3    ic4      ic5    avggift  target_d
# 0                         392  430.0  466  520.0  21975.0  28.000000     100.0
# 1                         365  415.0  410  473.0  19387.0   5.666667       7.0
# ...

# %%
#There would be a column with the sequence of numbers (to the left of column id). Drop that column(s).

data2=data2.drop('id', axis=1)
data2
# Out:
#       Unnamed: 0 state gender  median_home_val  median_household_income  \
# 0              0    FL      M      1158.437751                      392
# 1              1    IL      M       537.000000                      365
# 2              2    FL      F       725.000000                      301
# 3              3    NC      M      1158.437751                      401
# 4              4    FL      F       995.000000                      252
# ...          ...   ...    ...              ...                      ...
# 3988         996    MI      F       632.000000                      279
# 3989         997    FL      M       595.000000                      252
# 3990         998    CA      F      2707.000000                      507
# 3991         999    CA      M      2666.000000                      535
# 3992        1000    MI      M       444.000000                      225
#
#         ic2  ic3    ic4      ic5    avggift  target_d
# ...

# %%
#Check the column state for null values. Replace those null values with the state that is represented largest number of times in that column
sum(data2["state"].isnull())
# No hay valores nulos
# Out:
# 0

# %%
# Lambda Expression:
# Create a simple lambda expression to add three numbers. Take those three numbers as input from the user. 
a=int(input('Dame un numero'))
b=int(input('Dame un segundo numero'))
c=int(input('Dame un tercer numero'))
funcion1=lambda a,b,c: a+b+c
funcion1(a,b,c)
# Out:
# 3

# %%
#Define a list as lst = [1,2,3,4,5,6,7,8,10]. Write a lambda expression to find the cube of a number. 
# Use that lambda expression to find the cube of every number in the list. 
# Define a list comprehension for this question.
# , map como metodo de un objeto (pandas)
lst =pd.Series([1,2,3,4,5,6,7,8,10]) 
lista_nueva=lst.map(lambda x: x**3)
print(lista_nueva)
# Out:
# 0       1
# 1       8
# 2      27
# 3      64
# 4     125
# 5     216
# 6     343
# 7     512
# 8    1000
# dtype: int64

# %%
# Otra manera de hacerlo
# como instruccion directa de phyton
cube = list(map(lambda x : x*x*x, lst))
cube
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 1000]

# %% [markdown]
# # 1.04 Activity 3

# %% [markdown]
# Try to convert these functions into lambda functions.

# %%
#Funcion 1
def function_1(a,b):
    c=a+b
    return c
function_1(1,2) #Ejemplo
# Out:
# 3

# %%
#lambda
c=lambda a, b : a+b
c(1,2)    #Ejemplo
# Out:
# 3

# %%
#Funcion 2
def function_2(a,b):
    c=0
    for i in range(a):
        c+=2*b   # c += 2*b o c = c + 2*b
    return c
function_2(6,9)
# Out:
# 108

# %%
# Que pasa si c no empieza en cero?
c=lambda a,b : 2*b*a
c(6,9)
# Out:
# 108

# %%
#otra manera de hacerlo
c2=lambda a,b : sum([2*b for i in range (a)])

# %%
c2(6,9)
# Out:
# 108

# %%
def function_3(a,b):
    c=0
    if a>3:
        c=12
    else:
        c='Too big.'
    return c

# %%
c=lambda a, b :  12 if a > 3   else 'too big'
c(1,2)
# Out:
# 'too big'

# %% [markdown]
# # 1.04 Activity 4

# %% [markdown]
# ## Create a user-defined method to clean the column state in the dataframe.

# %%
data2['state'].unique()
# Out:
# array(['FL', 'IL', 'NC', 'TX', 'CA', 'NV', 'Cali', 'AP', 'MI', 'OK', 'AR',
#        'IN', 'MT', 'WI', 'MO', 'HI', 'UT', 'GA', 'WA', 'ID', 'CT', 'AL',
#        'ND', 'SC', 'IA', 'CO', 'LA', 'OR', 'SD', 'TN', 'NM', 'AZ', 'MN',
#        'KY', 'NJ', 'NE', 'KS', 'California', 'MS', 'NY', 'Arizona', 'WY',
#        'Tennessee', 'MD', 'AK', 'VA', 'AE', 'AA', 'PA', 'VT', 'WV', 'GU'],
#       dtype=object)

# %%
data2['state']
# Out:
# 0       FL
# 1       IL
# 2       FL
# 3       NC
# 4       FL
#         ..
# 3988    MI
# 3989    FL
# 3990    CA
# 3991    CA
# 3992    MI
# Name: state, Length: 3993, dtype: object

# %%
#Pasamos todos los registros a mayusculas para poder trabajar con ellas
#data2['state']=data2['state'].map(lambda x: x.upper())
#data2

# %%
#Comprobamos
#data2['state'].unique()

# %%
#Encontrar los registros que tenemos que limpiar, no tenemos valores nulos
#for i in data2['state']:
#   if len(i)>2:
#      print(i)

# %%
#ver la longitud de todos los registros de state
#for i in data2['state'] : print(len(i))

# %%
#pedir que me cambie todos los registros con longitud mayor a 2 a solo sus 2 primeras letras con un string
#Esto solo aplicaria si los estados se acortaran con sus dos primeras letras

#data2['state']=data2['state'].str[:2]

# %%
#data2['state'].unique()

# %%
#Primero hay que pensar que me funcione para una entrada
def clean(state_name):
    state_name=state_name.upper()
    state_name=state_name.strip()
    if 'ARI' in state_name:
      return 'AR'
    elif 'TENN' in state_name:
      return 'TN'
    elif 'CALI' in state_name:
      return 'CA'
    else:
      return state_name

# %%
var='Arizona'
clean(var)
# Out:
# 'AR'

# %%
#Aplicar la funcion ya a toda la columna y pasar los outputs a una lista
#.map solo se puede usar en  variables y pbjetos de panda 
#map() es de python y te pide lista
#para poder guardar el resultado del map, casi siempre tiene que llevar el list
data2['state']=list(map(clean,data2['state']))
data2['state']
# Out:
# 0       FL
# 1       IL
# 2       FL
# 3       NC
# 4       FL
#         ..
# 3988    MI
# 3989    FL
# 3990    CA
# 3991    CA
# 3992    MI
# Name: state, Length: 3993, dtype: object

# %%
data2['state'].unique()
# Out:
# array(['FL', 'IL', 'NC', 'TX', 'CA', 'NV', 'AP', 'MI', 'OK', 'AR', 'IN',
#        'MT', 'WI', 'MO', 'HI', 'UT', 'GA', 'WA', 'ID', 'CT', 'AL', 'ND',
#        'SC', 'IA', 'CO', 'LA', 'OR', 'SD', 'TN', 'NM', 'AZ', 'MN', 'KY',
#        'NJ', 'NE', 'KS', 'MS', 'NY', 'WY', 'MD', 'AK', 'VA', 'AE', 'AA',
#        'PA', 'VT', 'WV', 'GU'], dtype=object)

# %%
data2
# Out:
#       Unnamed: 0 state gender  median_home_val  median_household_income  \
# 0              0    FL      M      1158.437751                      392
# 1              1    IL      M       537.000000                      365
# 2              2    FL      F       725.000000                      301
# 3              3    NC      M      1158.437751                      401
# 4              4    FL      F       995.000000                      252
# ...          ...   ...    ...              ...                      ...
# 3988         996    MI      F       632.000000                      279
# 3989         997    FL      M       595.000000                      252
# 3990         998    CA      F      2707.000000                      507
# 3991         999    CA      M      2666.000000                      535
# 3992        1000    MI      M       444.000000                      225
#
#         ic2  ic3    ic4      ic5    avggift  target_d
# ...
